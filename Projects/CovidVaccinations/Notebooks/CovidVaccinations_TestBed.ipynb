# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import missingno as mns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1. Data Preparation

# %%
# Load the data
data = pd.read_csv('../Data/country_vaccinations.csv')
data.head(5)
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN             15656.0
# 2                      NaN                     NaN             15656.0
# 3                      NaN                     NaN             11070.0
# 4                      NaN                     NaN              8776.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
# Check Countries
data['country'].unique()
# Out:
# array(['Argentina', 'Austria', 'Bahrain', 'Belgium', 'Bermuda', 'Brazil',
#        'Bulgaria', 'Canada', 'Chile', 'China', 'Costa Rica', 'Croatia',
#        'Cyprus', 'Czechia', 'Denmark', 'Ecuador', 'England', 'Estonia',
#        'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Ireland', 'Isle of Man',
#        'Israel', 'Italy', 'Kuwait', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malta', 'Mexico', 'Netherlands', 'Northern Cyprus',
#        'Northern Ireland', 'Norway', 'Oman', 'Panama', 'Poland',
#        'Portugal', 'Romania', 'Russia', 'Saudi Arabia', 'Scotland',
#        'Serbia', 'Seychelles', 'Singapore', 'Slovakia', 'Slovenia',
#        'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Arab Emirates',
#        'United Kingdom', 'United States', 'Wales'], dtype=object)

# %%
# Extract India data
ind_df = data[data['country'] == 'India']
ind_df.head(10)
# Out:
#     country iso_code        date  total_vaccinations  people_vaccinated  \
# 660   India      IND  2021-01-15                 0.0                0.0
# 661   India      IND  2021-01-16            191181.0           191181.0
# 662   India      IND  2021-01-17            224301.0           224301.0
# 663   India      IND  2021-01-18            454049.0           454049.0
# 664   India      IND  2021-01-19            674835.0           674835.0
# 665   India      IND  2021-01-20            806484.0           806484.0
# 666   India      IND  2021-01-21           1043534.0          1043534.0
# 667   India      IND  2021-01-22           1390592.0          1390592.0
# 668   India      IND  2021-01-23           1582201.0          1582201.0
# 669   India      IND  2021-01-24           1615504.0          1615504.0
#
#      people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 660                      NaN                     NaN                 NaN
# ...

# %%
# Check the date range
print(f"Data is from {ind_df['date'].min()} to {ind_df['date'].max()}")
# Out:
# Data is from 2021-01-15 to 2021-01-26

# %%
ind_df.shape
# Out:
# (12, 15)

# %%
ind_df.isnull().sum()
# Out:
# country                                 0
# iso_code                                0
# date                                    0
# total_vaccinations                      0
# people_vaccinated                       0
# people_fully_vaccinated                12
# daily_vaccinations_raw                  1
# daily_vaccinations                      1
# total_vaccinations_per_hundred          0
# people_vaccinated_per_hundred           0
# people_fully_vaccinated_per_hundred    12
# daily_vaccinations_per_million          1
# vaccines                                0
# source_name                             0
# source_website                          0
# dtype: int64
