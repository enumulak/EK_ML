# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import missingno as mns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the data
data = pd.read_csv('../Data/covid19indiaorg/raw_data22.csv')

# %%
# Make a copy of the data
rd_df = data.copy()

# %%
rd_df.head()
# Out:
#    Entry_ID  State Patient Number Date Announced  Age Bracket Gender  \
# 0    453529                   NaN     09/01/2021          NaN    NaN
# 1    453530                   NaN     09/01/2021          NaN    NaN
# 2    453531                   NaN     09/01/2021          NaN    NaN
# 3    453532                   NaN     09/01/2021          NaN    NaN
# 4    453533                   NaN     09/01/2021          NaN    NaN
#
#   Detected City     Detected District Detected State State code  Num Cases  \
# 0           NaN                   NaN      Telangana         TG        474
# 1           NaN                   NaN      Telangana         TG          2
# 2           NaN              Adilabad      Telangana         TG          4
# 3           NaN  Bhadradri Kothagudem      Telangana         TG          8
# 4           NaN             Hyderabad      Telangana         TG         61
#
#   Current Status  Contracted from which Patient (Suspected) Notes  \
# ...

# %%
rd_df.shape
# Out:
# (25791, 20)

# %%
rd_df.isnull().sum()
# Out:
# Entry_ID                                         0
# State Patient Number                         25791
# Date Announced                                   0
# Age Bracket                                  25776
# Gender                                       25776
# Detected City                                25790
# Detected District                              366
# Detected State                                   0
# State code                                       0
# Num Cases                                        0
# Current Status                                   0
# Contracted from which Patient (Suspected)    25791
# Notes                                        25752
# Source_1                                       581
# Source_2                                     24176
# Source_3                                     25791
# Nationality                                  25791
# Type of transmission                         25791
# ...
