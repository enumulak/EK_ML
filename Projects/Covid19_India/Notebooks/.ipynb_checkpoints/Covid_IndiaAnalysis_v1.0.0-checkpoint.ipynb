# %% [markdown]
# ## Covid19 India: Predictive Modeling
#
# **To-Do:** General information on project, including information, material pertaining to subject matter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
import os

# %% [markdown]
# ## 1. Data Preparation and Feature Engineering

# %%
# Load the data
data = pd.read_csv('../Data/covid19indiaorg/states.csv')
data.head(10)
# Out:
#          Date   State  Confirmed  Recovered  Deceased  Other     Tested
# 0  2020-01-30  Kerala          1          0         0      0        NaN
# 1  2020-01-30   India          1          0         0      0        NaN
# 2  2020-02-02  Kerala          2          0         0      0        NaN
# 3  2020-02-02   India          2          0         0      0        NaN
# 4  2020-02-03  Kerala          3          0         0      0        NaN
# 5  2020-02-03   India          3          0         0      0        NaN
# 6  2020-02-14  Kerala          3          3         0      0        NaN
# 7  2020-02-14   India          3          3         0      0        NaN
# 8  2020-02-20  Kerala          3          3         0      0        NaN
# 9  2020-02-20  Punjab          0          0         0      0  3675493.0

# %%
data.tail()
# Out:
#              Date          State  Confirmed  Recovered  Deceased  Other  \
# 10450  2020-12-31        Tripura      33261      32728       382     23
# 10451  2020-12-31          India   10286310    9881732    149018   2861
# 10452  2020-12-31  Uttar Pradesh     584966     562459      8352      0
# 10453  2020-12-31    Uttarakhand      90920      83506      1509   1186
# 10454  2020-12-31    West Bengal     552063     530366      9712      0
#
#             Tested
# 10450     578723.0
# 10451  173111994.0
# 10452   23943169.0
# 10453    1777371.0
# 10454    7110430.0

# %%
# Extract India data
ind_df = data[data['State'] == 'India']
ind_df
# Out:
#              Date  State  Confirmed  Recovered  Deceased  Other       Tested
# 1      2020-01-30  India          1          0         0      0          NaN
# 3      2020-02-02  India          2          0         0      0          NaN
# 5      2020-02-03  India          3          0         0      0          NaN
# 7      2020-02-14  India          3          3         0      0          NaN
# 10     2020-02-20  India          3          3         0      0          NaN
# ...           ...    ...        ...        ...       ...    ...          ...
# 10307  2020-12-27  India   10208725    9781945    147940   2812  168818354.0
# 10343  2020-12-28  India   10224797    9806767    148190   2825  169802049.0
# 10379  2020-12-29  India   10245339    9833356    148475   2837  170922330.0
# 10415  2020-12-30  India   10267284    9859763    148774   2852  172049574.0
# 10451  2020-12-31  India   10286310    9881732    149018   2861  173111994.0
#
# [310 rows x 7 columns]

# %%
ind_df.shape
# Out:
# (310, 7)

# %%
# Rename columns
ind_df.columns = ['Date', 'Region', 'Total Confirmed', 'Total Recovered', 'Total Deceased', 'Other', 'Total Tested']
ind_df
# Out:
#              Date Region  Total Confirmed  Total Recovered  Total Deceased  \
# 1      2020-01-30  India                1                0               0
# 3      2020-02-02  India                2                0               0
# 5      2020-02-03  India                3                0               0
# 7      2020-02-14  India                3                3               0
# 10     2020-02-20  India                3                3               0
# ...           ...    ...              ...              ...             ...
# 10307  2020-12-27  India         10208725          9781945          147940
# 10343  2020-12-28  India         10224797          9806767          148190
# 10379  2020-12-29  India         10245339          9833356          148475
# 10415  2020-12-30  India         10267284          9859763          148774
# 10451  2020-12-31  India         10286310          9881732          149018
#
#        Other  Total Tested
# 1          0           NaN
# 3          0           NaN
# 5          0           NaN
# 7          0           NaN
# 10         0           NaN
# ...      ...           ...
# 10307   2812   168818354.0
# 10343   2825   169802049.0
# 10379   2837   170922330.0
# 10415   2852   172049574.0
# 10451   2861   173111994.0
#
# [310 rows x 7 columns]

# %%
# Basic info
ind_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 1 to 10451
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             310 non-null    object
#  1   Region           310 non-null    object
#  2   Total Confirmed  310 non-null    int64
#  3   Total Recovered  310 non-null    int64
#  4   Total Deceased   310 non-null    int64
#  5   Other            310 non-null    int64
#  6   Total Tested     294 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 19.4+ KB

# %% [markdown]
# **Feature 1: Create a new column for Active Cases**
#
# Formula: active = total_confirmed - (total_recovered + other + total_deceased)

# %%
ind_df['Active'] = ind_df['Total Confirmed'] - (ind_df['Total Recovered'] + ind_df['Other'] + ind_df['Total Deceased'])
ind_df['Active']
# Out:
# 1             1
# 3             2
# 5             3
# 7             0
# 10            0
#           ...
# 10307    276028
# 10343    267015
# 10379    260671
# 10415    255895
# 10451    252699
# Name: Active, Length: 310, dtype: int64

# %%
# Delete the 'other' column
ind_df = ind_df.drop(['Other'], axis = 1)
ind_df
# Out:
#              Date Region  Total Confirmed  Total Recovered  Total Deceased  \
# 1      2020-01-30  India                1                0               0
# 3      2020-02-02  India                2                0               0
# 5      2020-02-03  India                3                0               0
# 7      2020-02-14  India                3                3               0
# 10     2020-02-20  India                3                3               0
# ...           ...    ...              ...              ...             ...
# 10307  2020-12-27  India         10208725          9781945          147940
# 10343  2020-12-28  India         10224797          9806767          148190
# 10379  2020-12-29  India         10245339          9833356          148475
# 10415  2020-12-30  India         10267284          9859763          148774
# 10451  2020-12-31  India         10286310          9881732          149018
#
#        Total Tested  Active
# 1               NaN       1
# 3               NaN       2
# 5               NaN       3
# 7               NaN       0
# 10              NaN       0
# ...             ...     ...
# 10307   168818354.0  276028
# 10343   169802049.0  267015
# 10379   170922330.0  260671
# 10415   172049574.0  255895
# 10451   173111994.0  252699
#
# [310 rows x 7 columns]

# %% [markdown]
# **Feature 2: Create new columns for daily_confirmed, daily_recovered and daily_deceased cases**
#
# Initialize the new columns to 0

# %%
ind_df['Daily Confirmed'] = 0
ind_df['Daily Recovered'] = 0
ind_df['Daily Deceased'] = 0

# %% [markdown]
# Compute the values for daily_confirmed (subtract total_confirmed value of a row from the value of the previous row)

# %%
ind_df['Daily Confirmed'] = ind_df['Total Confirmed'] - ind_df['Total Confirmed'].shift(1)
ind_df['Daily Confirmed']
# Out:
# 1            NaN
# 3            1.0
# 5            1.0
# 7            0.0
# 10           0.0
#           ...
# 10307    20333.0
# 10343    16072.0
# 10379    20542.0
# 10415    21945.0
# 10451    19026.0
# Name: Daily Confirmed, Length: 310, dtype: float64

# %% [markdown]
# Compute the values for daily_recovered (subtract total_recovered value of a row from the previous row value)

# %%
ind_df['Daily Recovered'] = ind_df['Total Recovered'] - ind_df['Total Recovered'].shift(1)
ind_df['Daily Recovered']
# Out:
# 1            NaN
# 3            0.0
# 5            0.0
# 7            3.0
# 10           0.0
#           ...
# 10307    21097.0
# 10343    24822.0
# 10379    26589.0
# 10415    26407.0
# 10451    21969.0
# Name: Daily Recovered, Length: 310, dtype: float64

# %% [markdown]
# Compute the values for daily_deceased (subtract total_deceased value of a row from the previous row value)

# %%
ind_df['Daily Deceased'] = ind_df['Total Deceased'] - ind_df['Total Deceased'].shift(1)
ind_df['Daily Deceased']
# Out:
# 1          NaN
# 3          0.0
# 5          0.0
# 7          0.0
# 10         0.0
#          ...
# 10307    281.0
# 10343    250.0
# 10379    285.0
# 10415    299.0
# 10451    244.0
# Name: Daily Deceased, Length: 310, dtype: float64

# %%
# check null values
ind_df.isnull().sum()
# Out:
# Date                0
# Region              0
# Total Confirmed     0
# Total Recovered     0
# Total Deceased      0
# Total Tested       16
# Active              0
# Daily Confirmed     1
# Daily Recovered     1
# Daily Deceased      1
# dtype: int64

# %%
# Drop all null values
ind_df = ind_df.dropna()

# %%
mns.matrix(ind_df);

# %%
# Try to convert float columns to int
ind_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 131 to 10451
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             294 non-null    object
#  1   Region           294 non-null    object
#  2   Total Confirmed  294 non-null    int64
#  3   Total Recovered  294 non-null    int64
#  4   Total Deceased   294 non-null    int64
#  5   Total Tested     294 non-null    float64
#  6   Active           294 non-null    int64
#  7   Daily Confirmed  294 non-null    float64
#  8   Daily Recovered  294 non-null    float64
#  9   Daily Deceased   294 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 25.3+ KB

# %%
ind_df['Daily Confirmed'] = ind_df['Daily Confirmed'].astype('int64')

# %%
ind_df['Daily Recovered'] = ind_df['Daily Recovered'].astype('int64')

# %%
ind_df['Daily Deceased'] = ind_df['Daily Deceased'].astype('int64')

# %%
ind_df['Total Tested'] = ind_df['Total Tested'].astype('int64')

# %%
ind_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 131 to 10451
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             294 non-null    object
#  1   Region           294 non-null    object
#  2   Total Confirmed  294 non-null    int64
#  3   Total Recovered  294 non-null    int64
#  4   Total Deceased   294 non-null    int64
#  5   Total Tested     294 non-null    int64
#  6   Active           294 non-null    int64
#  7   Daily Confirmed  294 non-null    int64
#  8   Daily Recovered  294 non-null    int64
#  9   Daily Deceased   294 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 25.3+ KB

# %% [markdown]
# **Feature 3: Create a new column to store daily tests**

# %%
ind_df['Daily Tested'] = ind_df['Total Tested'] - ind_df['Total Tested'].shift(1)
ind_df['Daily Tested']
# Out:
# 131            NaN
# 146            0.0
# 161            0.0
# 178            0.0
# 196            0.0
#            ...
# 10307     715397.0
# 10343     983695.0
# 10379    1120281.0
# 10415    1127244.0
# 10451    1062420.0
# Name: Daily Tested, Length: 294, dtype: float64

# %%
# Check if there are '0' tests on any given day (this means that total tests for that day were the same as previous day)
no_tests = ind_df[ind_df['Daily Tested'] == 0]
no_tests
# Out:
#             Date Region  Total Confirmed  Total Recovered  Total Deceased  \
# 146   2020-03-14  India              102                3               1
# 161   2020-03-15  India              112                3               1
# 178   2020-03-16  India              126                3               1
# 196   2020-03-17  India              146                3               1
# 439   2020-03-27  India              883                8               3
# 467   2020-03-28  India             1019                8               3
# 495   2020-03-29  India             1139               99              28
# 1222  2020-04-20  India            18544             3273             593
#
#       Total Tested  Active  Daily Confirmed  Daily Recovered  Daily Deceased  \
# 146           6500      95               11                0               0
# 161           6500     105               10                0               0
# 178           6500     119               14                0               0
# 196           6500     139               20                0               0
# 439          27688     869              153                2               1
# 467          27688    1005              136                0               0
# 495          27688    1009              120               91              25
# 1222        401586   14675             1239              419              33
#
#       Daily Tested
# 146            0.0
# 161            0.0
# 178            0.0
# 196            0.0
# 439            0.0
# 467            0.0
# 495            0.0
# 1222           0.0

# %%
ind_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 131 to 10451
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             294 non-null    object
#  1   Region           294 non-null    object
#  2   Total Confirmed  294 non-null    int64
#  3   Total Recovered  294 non-null    int64
#  4   Total Deceased   294 non-null    int64
#  5   Total Tested     294 non-null    int64
#  6   Active           294 non-null    int64
#  7   Daily Confirmed  294 non-null    int64
#  8   Daily Recovered  294 non-null    int64
#  9   Daily Deceased   294 non-null    int64
#  10  Daily Tested     293 non-null    float64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 27.6+ KB

# %% [markdown]
# '0' daily tests basically means that the total tests were the same as the previous day. For example, tests done on two consecutive days would be the same - let's say 100000. In this case the increase or decrease in the number of daily tests is 0. If on the first day, the positivity rate is calculated, then perhaps we should use the same daily tests value to calculate positiviy rate for second day. We will come back to this later...

# %% [markdown]
# **Feature 4: Create a new column to store overall recovery rate**

# %%
ind_df['TRR'] = np.round((ind_df['Total Recovered'] / ind_df['Total Confirmed'] * 100), 2)
ind_df['TRR']
# Out:
# 131       3.30
# 146       2.94
# 161       2.68
# 178       2.38
# 196       2.05
#          ...
# 10307    95.82
# 10343    95.91
# 10379    95.98
# 10415    96.03
# 10451    96.07
# Name: TRR, Length: 294, dtype: float64

# %% [markdown]
# **Feature 5: Create a new column to store overall positivity rate**

# %%
ind_df['TPR'] = np.round((ind_df['Total Confirmed'] / ind_df['Total Tested'] * 100), 2)
ind_df['TPR']
# Out:
# 131      1.40
# 146      1.57
# 161      1.72
# 178      1.94
# 196      2.25
#          ...
# 10307    6.05
# 10343    6.02
# 10379    5.99
# 10415    5.97
# 10451    5.94
# Name: TPR, Length: 294, dtype: float64

# %% [markdown]
# **Feature 6: Create a new column to store overall case fatality rate**

# %%
ind_df['CFR'] = np.round((ind_df['Total Deceased'] / ind_df['Total Confirmed'] * 100), 2)
ind_df['CFR']
# Out:
# 131      1.10
# 146      0.98
# 161      0.89
# 178      0.79
# 196      0.68
#          ...
# 10307    1.45
# 10343    1.45
# 10379    1.45
# 10415    1.45
# 10451    1.45
# Name: CFR, Length: 294, dtype: float64

# %% [markdown]
# Convert the 'date' column to DateTime type

# %%
ind_df['Date'] = pd.to_datetime(ind_df['Date'])
ind_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 131 to 10451
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             294 non-null    datetime64[ns]
#  1   Region           294 non-null    object
#  2   Total Confirmed  294 non-null    int64
#  3   Total Recovered  294 non-null    int64
#  4   Total Deceased   294 non-null    int64
#  5   Total Tested     294 non-null    int64
#  6   Active           294 non-null    int64
#  7   Daily Confirmed  294 non-null    int64
#  8   Daily Recovered  294 non-null    int64
#  9   Daily Deceased   294 non-null    int64
#  10  Daily Tested     293 non-null    float64
#  11  TRR              294 non-null    float64
#  12  TPR              294 non-null    float64
#  13  CFR              294 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(1)
# memory usage: 34.5+ KB

# %%
# Let's extract month, weekday and create new columns for them
ind_df['Month'] = pd.DatetimeIndex(ind_df.Date).month
ind_df['Weekday'] = pd.DatetimeIndex(ind_df.Date).weekday

# Check how the data set looks now
ind_df.head(10)
# Out:
#           Date Region  Total Confirmed  Total Recovered  Total Deceased  \
# 131 2020-03-13  India               91                3               1
# 146 2020-03-14  India              102                3               1
# 161 2020-03-15  India              112                3               1
# 178 2020-03-16  India              126                3               1
# 196 2020-03-17  India              146                3               1
# 215 2020-03-18  India              171                3               1
# 237 2020-03-19  India              198                3               1
# 260 2020-03-20  India              256                4               1
# 283 2020-03-21  India              334                4               1
# 307 2020-03-22  India              403                4               1
#
#      Total Tested  Active  Daily Confirmed  Daily Recovered  Daily Deceased  \
# 131          6500      87               10                0               1
# 146          6500      95               11                0               0
# 161          6500     105               10                0               0
# 178          6500     119               14                0               0
# 196          6500     139               20                0               0
# 215         13125     164               25                0               0
# 237         14175     191               27                0               0
# 260         15404     248               58                1               0
# 283         16911     326               78                0               0
# 307         18127     395               69                0               0
#
#      Daily Tested   TRR   TPR   CFR  Month  Weekday
# 131           NaN  3.30  1.40  1.10      3        4
# 146           0.0  2.94  1.57  0.98      3        5
# 161           0.0  2.68  1.72  0.89      3        6
# 178           0.0  2.38  1.94  0.79      3        0
# 196           0.0  2.05  2.25  0.68      3        1
# 215        6625.0  1.75  1.30  0.58      3        2
# 237        1050.0  1.52  1.40  0.51      3        3
# 260        1229.0  1.56  1.66  0.39      3        4
# 283        1507.0  1.20  1.98  0.30      3        5
# 307        1216.0  0.99  2.22  0.25      3        6

# %%
ind_df = ind_df.dropna()
ind_df.head(10)
# Out:
#           Date Region  Total Confirmed  Total Recovered  Total Deceased  \
# 146 2020-03-14  India              102                3               1
# 161 2020-03-15  India              112                3               1
# 178 2020-03-16  India              126                3               1
# 196 2020-03-17  India              146                3               1
# 215 2020-03-18  India              171                3               1
# 237 2020-03-19  India              198                3               1
# 260 2020-03-20  India              256                4               1
# 283 2020-03-21  India              334                4               1
# 307 2020-03-22  India              403                4               1
# 331 2020-03-23  India              497                4               1
#
#      Total Tested  Active  Daily Confirmed  Daily Recovered  Daily Deceased  \
# 146          6500      95               11                0               0
# 161          6500     105               10                0               0
# 178          6500     119               14                0               0
# 196          6500     139               20                0               0
# 215         13125     164               25                0               0
# 237         14175     191               27                0               0
# 260         15404     248               58                1               0
# 283         16911     326               78                0               0
# 307         18127     395               69                0               0
# 331         20707     489               94                0               0
#
#      Daily Tested   TRR   TPR   CFR  Month  Weekday
# 146           0.0  2.94  1.57  0.98      3        5
# 161           0.0  2.68  1.72  0.89      3        6
# 178           0.0  2.38  1.94  0.79      3        0
# 196           0.0  2.05  2.25  0.68      3        1
# 215        6625.0  1.75  1.30  0.58      3        2
# 237        1050.0  1.52  1.40  0.51      3        3
# 260        1229.0  1.56  1.66  0.39      3        4
# 283        1507.0  1.20  1.98  0.30      3        5
# 307        1216.0  0.99  2.22  0.25      3        6
# 331        2580.0  0.80  2.40  0.20      3        0

# %%
# Reset index for the data set
ind_df = ind_df.reset_index()
ind_df.head(10)
# Out:
#    index       Date Region  Total Confirmed  Total Recovered  Total Deceased  \
# 0    146 2020-03-14  India              102                3               1
# 1    161 2020-03-15  India              112                3               1
# 2    178 2020-03-16  India              126                3               1
# 3    196 2020-03-17  India              146                3               1
# 4    215 2020-03-18  India              171                3               1
# 5    237 2020-03-19  India              198                3               1
# 6    260 2020-03-20  India              256                4               1
# 7    283 2020-03-21  India              334                4               1
# 8    307 2020-03-22  India              403                4               1
# 9    331 2020-03-23  India              497                4               1
#
#    Total Tested  Active  Daily Confirmed  Daily Recovered  Daily Deceased  \
# 0          6500      95               11                0               0
# 1          6500     105               10                0               0
# 2          6500     119               14                0               0
# 3          6500     139               20                0               0
# 4         13125     164               25                0               0
# 5         14175     191               27                0               0
# 6         15404     248               58                1               0
# 7         16911     326               78                0               0
# 8         18127     395               69                0               0
# 9         20707     489               94                0               0
#
#    Daily Tested   TRR   TPR   CFR  Month  Weekday
# 0           0.0  2.94  1.57  0.98      3        5
# 1           0.0  2.68  1.72  0.89      3        6
# 2           0.0  2.38  1.94  0.79      3        0
# 3           0.0  2.05  2.25  0.68      3        1
# 4        6625.0  1.75  1.30  0.58      3        2
# 5        1050.0  1.52  1.40  0.51      3        3
# 6        1229.0  1.56  1.66  0.39      3        4
# 7        1507.0  1.20  1.98  0.30      3        5
# 8        1216.0  0.99  2.22  0.25      3        6
# 9        2580.0  0.80  2.40  0.20      3        0

# %%
ind_df = ind_df.drop(['index'], axis = 1)
ind_df
# Out:
#           Date Region  Total Confirmed  Total Recovered  Total Deceased  \
# 0   2020-03-14  India              102                3               1
# 1   2020-03-15  India              112                3               1
# 2   2020-03-16  India              126                3               1
# 3   2020-03-17  India              146                3               1
# 4   2020-03-18  India              171                3               1
# ..         ...    ...              ...              ...             ...
# 288 2020-12-27  India         10208725          9781945          147940
# 289 2020-12-28  India         10224797          9806767          148190
# 290 2020-12-29  India         10245339          9833356          148475
# 291 2020-12-30  India         10267284          9859763          148774
# 292 2020-12-31  India         10286310          9881732          149018
#
#      Total Tested  Active  Daily Confirmed  Daily Recovered  Daily Deceased  \
# 0            6500      95               11                0               0
# 1            6500     105               10                0               0
# 2            6500     119               14                0               0
# 3            6500     139               20                0               0
# 4           13125     164               25                0               0
# ..            ...     ...              ...              ...             ...
# 288     168818354  276028            20333            21097             281
# 289     169802049  267015            16072            24822             250
# 290     170922330  260671            20542            26589             285
# 291     172049574  255895            21945            26407             299
# 292     173111994  252699            19026            21969             244
#
#      Daily Tested    TRR   TPR   CFR  Month  Weekday
# 0             0.0   2.94  1.57  0.98      3        5
# 1             0.0   2.68  1.72  0.89      3        6
# 2             0.0   2.38  1.94  0.79      3        0
# 3             0.0   2.05  2.25  0.68      3        1
# 4          6625.0   1.75  1.30  0.58      3        2
# ..            ...    ...   ...   ...    ...      ...
# 288      715397.0  95.82  6.05  1.45     12        6
# 289      983695.0  95.91  6.02  1.45     12        0
# 290     1120281.0  95.98  5.99  1.45     12        1
# 291     1127244.0  96.03  5.97  1.45     12        2
# 292     1062420.0  96.07  5.94  1.45     12        3
#
# [293 rows x 16 columns]

# %%
# Save this data frame as a csv for future purposes
#ind_df.to_csv('../Data/covid19indiaorg/India_Transformed.csv', index = False)

# %% [markdown]
# **To-Do:** Perhaps we should also have daily recovery rate, daily fatality rate and daily positivity rate

# %% [markdown]
# ## 2. Visualizations

# %% [markdown]
# Visualizations:
#
# 1. daily confirmed, daily recovered, daily tested
# 2. total confirmed, total recovered, total tested
# 3. total recovery rate, total positivity rate, total fatality rate
# 4. daily recovery, daily fatality, daily positivity (if columns are created)

# %%
# Set date as the index
ind_df.set_index('Date', inplace = True)
ind_df
# Out:
#            Region  Total Confirmed  Total Recovered  Total Deceased  \
# Date
# 2020-03-14  India              102                3               1
# 2020-03-15  India              112                3               1
# 2020-03-16  India              126                3               1
# 2020-03-17  India              146                3               1
# 2020-03-18  India              171                3               1
# ...           ...              ...              ...             ...
# 2020-12-27  India         10208725          9781945          147940
# 2020-12-28  India         10224797          9806767          148190
# 2020-12-29  India         10245339          9833356          148475
# 2020-12-30  India         10267284          9859763          148774
# 2020-12-31  India         10286310          9881732          149018
#
#             Total Tested  Active  Daily Confirmed  Daily Recovered  \
# Date
# 2020-03-14          6500      95               11                0
# 2020-03-15          6500     105               10                0
# 2020-03-16          6500     119               14                0
# 2020-03-17          6500     139               20                0
# 2020-03-18         13125     164               25                0
# ...                  ...     ...              ...              ...
# 2020-12-27     168818354  276028            20333            21097
# 2020-12-28     169802049  267015            16072            24822
# 2020-12-29     170922330  260671            20542            26589
# 2020-12-30     172049574  255895            21945            26407
# 2020-12-31     173111994  252699            19026            21969
#
#             Daily Deceased  Daily Tested    TRR   TPR   CFR  Month  Weekday
# Date
# 2020-03-14               0           0.0   2.94  1.57  0.98      3        5
# 2020-03-15               0           0.0   2.68  1.72  0.89      3        6
# 2020-03-16               0           0.0   2.38  1.94  0.79      3        0
# 2020-03-17               0           0.0   2.05  2.25  0.68      3        1
# 2020-03-18               0        6625.0   1.75  1.30  0.58      3        2
# ...                    ...           ...    ...   ...   ...    ...      ...
# 2020-12-27             281      715397.0  95.82  6.05  1.45     12        6
# 2020-12-28             250      983695.0  95.91  6.02  1.45     12        0
# 2020-12-29             285     1120281.0  95.98  5.99  1.45     12        1
# 2020-12-30             299     1127244.0  96.03  5.97  1.45     12        2
# 2020-12-31             244     1062420.0  96.07  5.94  1.45     12        3
#
# [293 rows x 15 columns]

# %%
plt.figure(figsize=(15,8))
ind_df['CFR'].plot(ls='--', lw=2, legend=True)

plt.xlabel('Date')
plt.ylabel('CFR (%)')
plt.title('India - Case Fatality Rate');
