# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import missingno as mns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the data
data = pd.read_csv('../Data/covid19indiaorg/raw_data24.csv')

# %%
# Make a copy of the data
rd_df = data.copy()

# %%
rd_df.head()
# Out:
#    Entry_ID  State Patient Number Date Announced  Age Bracket Gender  \
# 0    503873                   NaN     28/02/2021          NaN    NaN
# 1    503874                   NaN     28/02/2021          NaN    NaN
# 2    503875                   NaN     28/02/2021          NaN    NaN
# 3    503876                   NaN     28/02/2021          NaN    NaN
# 4    503877                   NaN     28/02/2021          NaN    NaN
#
#    Detected City     Detected District Detected State State code  Num Cases  \
# 0            NaN              Adilabad      Telangana         TG          6
# 1            NaN  Bhadradri Kothagudem      Telangana         TG          5
# 2            NaN             Hyderabad      Telangana         TG         27
# 3            NaN               Jagtial      Telangana         TG          9
# 4            NaN               Jangaon      Telangana         TG          2
#
#   Current Status  Contracted from which Patient (Suspected) Notes  \
# ...

# %%
rd_df.shape
# Out:
# (3456, 20)

# %%
rd_df.isnull().sum()
# Out:
# Entry_ID                                        0
# State Patient Number                         3456
# Date Announced                                  0
# Age Bracket                                  3393
# Gender                                       3393
# Detected City                                3456
# Detected District                              43
# Detected State                                  0
# State code                                      0
# Num Cases                                       0
# Current Status                                  0
# Contracted from which Patient (Suspected)    3456
# Notes                                        3455
# Source_1                                      131
# Source_2                                     3266
# Source_3                                     3456
# Nationality                                  3456
# Type of transmission                         3456
# Status Change Date                           3456
# ...
